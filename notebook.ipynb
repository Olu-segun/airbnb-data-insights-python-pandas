# %%
import pandas as pd

data_url = "https://raw.githubusercontent.com/Olu-segun/airbnb-data-insights-python-pandas/refs/heads/main/data/airbnb_listings.csv"

df = pd.read_csv(data_url)
# df.info()
# df.describe()
# df.head()
# df = df.dropna()
# print(df)

# %% [markdown]
# #### Data Cleaning

# %%
df_price = df['price']
